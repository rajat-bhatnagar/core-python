# %%
print('Demo 2')

for i  in range(5):
    print(i)
# Out:
# Demo 2
# 0
# 1
# 2
# 3
# 4

# %%
print('Hello World')
print(10 + 200)
# Out:
# Hello World
# 210

# %%
from datetime import datetime

current = datetime.utcnow()
current
# Out:
# datetime.datetime(2025, 11, 29, 2, 32, 25, 961853)

# %% [markdown]
# This is not **code**

# %%
1
# Out:
# 1

# %% [markdown]
# 1.0

# %%
-10.5
# Out:
# -10.5

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
format(0.1, '.25f')
# Out:
# '0.1000000000000000055511151'

# %%
format(0.125,'0.25f')
# Out:
# '0.1250000000000000000000000'

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %% [markdown]
# 0.1 + 0.1 + 0.1 == 0.3 ## This is false ,
#
# The expression 0.1 + 0.1 + 0.1 == 0.3 evaluates to False in Python because floating-point numbers like 0.1 cannot be represented exactly in binary inside the computer. Instead, they are stored as approximations, so the sum of three 0.1s is a number very close to but not exactly 0.3. When Python compares the sum to 0.3, it finds they are not exactly equal and returns False.
#
# This happens because Python uses binary floating-point arithmetic (IEEE 754 standard), where decimal fractions such as 0.1 have no exact binary representation, similar to how 1/3 cannot be exactly represented in decimal. For example, 0.1 might be stored as 0.100000000000000005 and 0.3 as 0.299999999999999988 internally, so the equality check fails accurately.

# %%
class Account:
    def __init__(self, account_number, account_type, initial_balance):
        self.account_number = account_number
        self.account_type = account_type
        self.balance = initial_balance

    def deposit(self, amount):
        # Should also check that amount is a numerical value
        if amount > 0:
            self.balance = self.balance + amount
            print(f'Deposited {amount}')
            print(f'New Balance is {self.balance}')
        else:
            print(f'{amount} is an invalid amount')

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance:
            self.balance = self.balance - amount
            print(f'Withdrew {amount}')
            print(f'New Balance is {self.balance}')
        else:
            if amount < 0:
                print(f'{amount} is an invalid amount')
            else:
                print(f'Insufficient funds to withdraw {amount}')

# %%
my_account = Account('123-456', 'savings', 1000)

# %%
my_account.account_number
# Out:
# '123-456'

# %%
 my_account.account_type
# Out:
# 'savings'

# %%
my_account.balance
# Out:
# 1000

# %%
my_account.deposit(100)
# Out:
# Deposited 100
# New Balance is 1100

# %%
my_account.withdraw(600)
# Out:
# Withdrew 600
# New Balance is 500

# %%
(10).__add__(25)
# Out:
# 35

# %%
(0.125).as_integer_ratio()
# Out:
# (1, 8)

# %%
(0.1).as_integer_ratio()
# Out:
# (3602879701896397, 36028797018963968)

# %%
a = 100

# %%
a
# Out:
# 100

# %%
a + 11
# Out:
# 111

# %%
a = float(10)
a
# Out:
# 10.0

# %%
principal = 100
apr = 0.1
years = 10

future_value = principal * ((1 + apr/12) ** years)
future_value
# Out:
# 108.65288007072382

# %%
2 ** 8
# Out:
# 256

# %%
2 ** (-8)
# Out:
# 0.00390625

# %%
c = (-4) ** 0.5
c
# Out:
# (1.2246467991473532e-16+2j)

# %%
type(c)
# Out:
# complex

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if isinstance(other, Vector):
          return Vector(self.x + other.x, self.y + other.y)

    def __repr__(self):
       return f'Vector({self.x}, {self.y})'

# %%
   v1 = Vector(2, 3)
   v2 = Vector(5, 7)

# %%
v1
# Out:
# Vector(2, 3)

# %%
v2
# Out:
# Vector(5, 7)

# %%
v1 + v2
# Out:
# Vector(7, 10)

# %%
-4 ** 0.5
# Out:
# -2.0

# %%
(-4) ** 0.5
# Out:
# (1.2246467991473532e-16+2j)

# %%
43 // 3
# Out:
# 14

# %%
43 % 3
# Out:
# 1

# %%
12 % -5
# Out:
# -3

# %%
-12 % 5
# Out:
# 3

# %% [markdown]
# a%b=a−b×[a/b]
#
# where [a/b] is the floor function, which gives the greatest integer less than or equal to a/b.

# %%
-12 % -5
# Out:
# -2

# %%
12.5 % 3
# Out:
# 0.5

# %%
-12 // 5
# Out:
# -3

# %%
10 % 3
# Out:
# 1

# %%
10 < 10.9
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %% [markdown]
# 0.1 + 0.1 == 0.2 is False in Python because float uses binary (base‑2) floating‑point, and numbers like 0.1 and 0.2 cannot be represented exactly in that format. Never use equality == to compare floats.
