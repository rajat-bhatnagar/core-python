# %%
print('Demo 2')

for i  in range(5):
    print(i)
# Out:
# Demo 2
# 0
# 1
# 2
# 3
# 4

# %%
print('Hello World')
print(10 + 200)
# Out:
# Hello World
# 210

# %%
from datetime import datetime

current = datetime.utcnow()
current
# Out:
# datetime.datetime(2025, 11, 29, 2, 32, 25, 961853)

# %% [markdown]
# This is not **code**
